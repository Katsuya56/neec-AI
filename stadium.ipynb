# %%
import pandas as pd

# %%
stadium = pd.read_csv("./input/stadium.csv")
stadium = stadium.drop("address", axis=1)
stadium = stadium.sort_values('capa', ascending=False)
stadium
# Out:
#                          name   capa
# 17                    日産スタジアム  72327
# 33                埼玉スタジアム２００２  63700
# 42                      国立競技場  54224
# 36                   エコパスタジアム  50889
# 9                エディオンスタジアム広島  50000
# 40                   味の素スタジアム  49970
# 50                    宮城スタジアム  49133
# 30                ヤンマースタジアム長居  47816
# 49          神戸総合運動公園ユニバー記念競技場  45000
# 25             デンカビッグスワンスタジアム  42300
# 13             県立カシマサッカースタジアム  40728
# 26                    大分銀行ドーム  40000
# 1                     豊田スタジアム  40000
# 10                      札幌ドーム  39232
# 20              うまかな・よかなスタジアム  32000
# 12                ノエビアスタジアム神戸  30132
# 16                   等々力陸上競技場  26530
# 45             富山県総合運動公園陸上競技場  25250
# 31              ベストアメニティスタジアム  24490
# 5                レベルファイブスタジアム  22563
# 58                  香川県立丸亀競技場  22338
# 46               ＮＤソフトスタジアム山形  21292
# 53               福島県営あづま陸上競技場  21000
# 28                    万博記念競技場  21000
# ...
